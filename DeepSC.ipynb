# %%
files.upload()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-63b259460c61> in <cell line: 1>()
# ----> 1 files.upload()
#
# NameError: name 'files' is not defined

# %%
# !cp /content/drive/MyDrive/Semantic_task4/*.py /content

# %%
# !wget http://www.statmt.org/europarl/v7/europarl.tgz
# Out:
# --2024-05-16 14:44:54--  http://www.statmt.org/europarl/v7/europarl.tgz
# Resolving www.statmt.org (www.statmt.org)... 129.215.32.28
# Connecting to www.statmt.org (www.statmt.org)|129.215.32.28|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://www.statmt.org/europarl/v7/europarl.tgz [following]
# --2024-05-16 14:44:54--  https://www.statmt.org/europarl/v7/europarl.tgz
# Connecting to www.statmt.org (www.statmt.org)|129.215.32.28|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1570461714 (1.5G) [application/x-gzip]
# Saving to: ‘europarl.tgz’
#
# europarl.tgz        100%[===================>]   1.46G  27.4MB/s    in 55s
#
# 2024-05-16 14:45:50 (27.0 MB/s) - ‘europarl.tgz’ saved [1570461714/1570461714]

# %%
# !tar zxvf europarl.tgz
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
# txt/fr/ep-10-10-19-010.txt
# txt/fr/ep-10-07-08-011-02.txt
# txt/fr/ep-08-04-23-012.txt
# txt/fr/ep-09-04-02-013.txt
# txt/fr/ep-11-06-23-012-04.txt
# txt/fr/ep-06-10-12-007-26.txt
# txt/fr/ep-08-07-10-021.txt
# txt/fr/ep-10-05-05-017.txt
# txt/fr/ep-09-02-04-005-01.txt
# txt/fr/ep-05-05-09.txt
# txt/fr/ep-08-01-23-002.txt
# txt/fr/ep-11-02-02-019.txt
# txt/fr/ep-06-12-11-010.txt
# txt/fr/ep-09-03-25-003-20.txt
# txt/fr/ep-11-05-11-016.txt
# txt/fr/ep-10-06-15-010.txt
# txt/fr/ep-08-11-20-006.txt
# txt/fr/ep-10-01-18-009.txt
# txt/fr/ep-08-06-04-003.txt
# txt/fr/ep-09-10-22-014.txt
# txt/fr/ep-10-07-08-006-09.txt
# txt/fr/ep-07-02-12-017.txt
# txt/fr/ep-11-01-18-007-06.txt
# txt/fr/ep-06-10-11-021.txt
# txt/fr/ep-07-04-24-020.txt
# txt/fr/ep-10-12-16-011.txt
# txt/fr/ep-09-05-04-022.txt
# txt/fr/ep-08-09-03-007-08.txt
# txt/fr/ep-10-05-18-010.txt
# txt/fr/ep-09-01-12-012.txt
# txt/fr/ep-09-02-05-007.txt
# ...

# %%
# !pip install pytorch
# !pip install nltk
# !pip install w3lib
# !pip install tqdm
# !pip install scikitlearn
# !pip install bert4keras
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ...
#   ERROR: Failed building wheel for pytorch
#   Running setup.py clean for pytorch
# Failed to build pytorch
# ERROR: Could not build wheels for pytorch, which is required to install pyproject.toml-based projects
# ...
# ERROR: Could not find a version that satisfies the requirement scikitlearn (from versions: none)
# ERROR: No matching distribution found for scikitlearn
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.2/54.2 kB 1.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 377.8/377.8 kB 7.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 6.7 MB/s eta 0:00:00
# ...

# %%
# !python preprocess_text.py
# Out:
# txt/en
# Preprocess Raw Text
# 100% 9672/9672 [02:27<00:00, 65.56it/s]
# Number of sentences: 73472
# Build Vocab
# Number of words in Vocab: 22234
# Start encoding txt
# 100% 73472/73472 [00:00<00:00, 181019.14it/s]
# Writing Data

# %%
# !python test.py
# Out:
# 2.2.1+cu121
# True
# Total GPU memory 14.7GB, alloc 0B, free 14.6GB (99.3%)

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2023 NVIDIA Corporation
# Built on Tue_Aug_15_22:02:13_PDT_2023
# Cuda compilation tools, release 12.2, V12.2.140
# Build cuda_12.2.r12.2/compiler.33191640_0

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
# !pip3 install torch torchvision torchaudio
# Out:
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# ...
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# ...

# %%
import dataset
import utils

# %%
# !python main.py
# Out:
# Epoch: 1;  Type: Train; Loss: 4.38070: 100% 517/517 [00:36<00:00, 14.07it/s]
# Epoch: 1; Type: VAL; Loss: 3.81091: 100% 58/58 [00:01<00:00, 40.44it/s]
# Epoch: 2;  Type: Train; Loss: 3.80636: 100% 517/517 [00:35<00:00, 14.56it/s]
# Epoch: 2; Type: VAL; Loss: 3.24135: 100% 58/58 [00:01<00:00, 40.26it/s]
# Epoch: 3;  Type: Train; Loss: 3.44827: 100% 517/517 [00:36<00:00, 14.22it/s]
# Epoch: 3; Type: VAL; Loss: 2.92559: 100% 58/58 [00:01<00:00, 39.92it/s]
# Epoch: 4;  Type: Train; Loss: 3.20199: 100% 517/517 [00:36<00:00, 14.05it/s]
# Epoch: 4; Type: VAL; Loss: 2.65230: 100% 58/58 [00:01<00:00, 36.54it/s]
# Epoch: 5;  Type: Train; Loss: 2.84545: 100% 517/517 [00:37<00:00, 13.94it/s]
# Epoch: 5; Type: VAL; Loss: 2.33028: 100% 58/58 [00:01<00:00, 39.07it/s]
# Epoch: 6;  Type: Train; Loss: 2.48359: 100% 517/517 [00:37<00:00, 13.80it/s]
# Epoch: 6; Type: VAL; Loss: 1.96522: 100% 58/58 [00:01<00:00, 38.64it/s]
# Epoch: 7;  Type: Train; Loss: 2.27518: 100% 517/517 [00:37<00:00, 13.67it/s]
# ...

# %%
from google.colab import files

files.download('/content/checkpoints/deepsc-Rayleigh/checkpoint_80.pth')

# %%
# !python performance.py --checkpoint-path /content/checkpoints/deepsc-Rayleigh
# Out:
# model load!
# 100% 7/7 [02:32<00:00, 21.74s/it]
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# ...

# %%
# !python main.py --channel Rician --checkpoint-path /content/checkpoints/deepsc-Rician
# Out:
# Epoch: 1;  Type: Train; Loss: 4.38417: 100% 517/517 [00:36<00:00, 14.31it/s]
# Epoch: 1; Type: VAL; Loss: 3.81415: 100% 58/58 [00:01<00:00, 40.94it/s]
# Epoch: 2;  Type: Train; Loss: 3.76444: 100% 517/517 [00:35<00:00, 14.44it/s]
# Epoch: 2; Type: VAL; Loss: 3.21908: 100% 58/58 [00:01<00:00, 40.01it/s]
# Epoch: 3;  Type: Train; Loss: 3.40313: 100% 517/517 [00:36<00:00, 14.21it/s]
# Epoch: 3; Type: VAL; Loss: 2.86537: 100% 58/58 [00:01<00:00, 39.50it/s]
# Epoch: 4;  Type: Train; Loss: 3.07207: 100% 517/517 [00:36<00:00, 14.00it/s]
# Epoch: 4; Type: VAL; Loss: 2.53802: 100% 58/58 [00:01<00:00, 38.52it/s]
# Epoch: 5;  Type: Train; Loss: 2.57795: 100% 517/517 [00:37<00:00, 13.90it/s]
# Epoch: 5; Type: VAL; Loss: 2.05577: 100% 58/58 [00:01<00:00, 37.22it/s]
# Epoch: 6;  Type: Train; Loss: 2.19534: 100% 517/517 [00:37<00:00, 13.79it/s]
# Epoch: 6; Type: VAL; Loss: 1.64382: 100% 58/58 [00:01<00:00, 38.52it/s]
# Epoch: 7;  Type: Train; Loss: 2.07364: 100% 517/517 [00:37<00:00, 13.67it/s]
# ...

# %%
# !python performance.py --checkpoint-path /content/checkpoints/deepsc-Rician
# Out:
# model load!
# 100% 7/7 [02:26<00:00, 20.91s/it]
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# ...

# %%
# !python main.py --channel AWGN --checkpoint-path /content/checkpoints/deepsc-AWGN
# Out:
# Epoch: 1;  Type: Train; Loss: 4.37526: 100% 517/517 [00:36<00:00, 14.21it/s]
# Epoch: 1; Type: VAL; Loss: 3.80194: 100% 58/58 [00:01<00:00, 38.10it/s]
# Epoch: 2;  Type: Train; Loss: 3.74234: 100% 517/517 [00:36<00:00, 14.23it/s]
# Epoch: 2; Type: VAL; Loss: 3.18949: 100% 58/58 [00:01<00:00, 40.13it/s]
# Epoch: 3;  Type: Train; Loss: 3.34217: 100% 517/517 [00:37<00:00, 13.88it/s]
# Epoch: 3; Type: VAL; Loss: 2.80196: 100% 58/58 [00:01<00:00, 39.45it/s]
# Epoch: 4;  Type: Train; Loss: 2.91390: 100% 517/517 [00:37<00:00, 13.91it/s]
# Epoch: 4; Type: VAL; Loss: 2.34205: 100% 58/58 [00:01<00:00, 37.25it/s]
# Epoch: 5;  Type: Train; Loss: 2.45991: 100% 517/517 [00:37<00:00, 13.83it/s]
# Epoch: 5; Type: VAL; Loss: 1.83932: 100% 58/58 [00:01<00:00, 38.82it/s]
# Epoch: 6;  Type: Train; Loss: 2.19533: 100% 517/517 [00:37<00:00, 13.68it/s]
# Epoch: 6; Type: VAL; Loss: 1.53279: 100% 58/58 [00:01<00:00, 38.53it/s]
# Epoch: 7;  Type: Train; Loss: 1.91774: 100% 517/517 [00:37<00:00, 13.68it/s]
# ...
